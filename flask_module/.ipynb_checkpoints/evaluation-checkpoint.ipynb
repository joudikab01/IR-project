# %%
# !pip3 install ir_measures
# !pip3 install joblib
# !pip3 install scikit-learn
# !pip3 install ir_measures
# !pip3 install numpy
# Out:
# Requirement already satisfied: ir_measures in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (0.3.3)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.5 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from ir_measures) (0.5.6)
# Requirement already satisfied: cwl-eval>=1.0.10 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from ir_measures) (1.0.12)
# Requirement already satisfied: numpy in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from cwl-eval>=1.0.10->ir_measures) (1.24.4)
# Requirement already satisfied: joblib in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (1.4.2)
# Requirement already satisfied: scikit-learn in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: ir_measures in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (0.3.3)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.5 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from ir_measures) (0.5.6)
# Requirement already satisfied: cwl-eval>=1.0.10 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from ir_measures) (1.0.12)
# Requirement already satisfied: numpy in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from cwl-eval>=1.0.10->ir_measures) (1.24.4)
# Requirement already satisfied: numpy in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (1.24.4)

# %%
import os
import joblib
from utils.constant import QuoraConstant, ClinicalConstant

os.chdir('/path/to/your/project/root')
class VectorizeQuery:
    project_root_dir = os.path.join(
       os.path.dirname(os.path.abspath('')),
        'vectorizer')
    quora_vectorizer = joblib.load( project_root_dir + '\\' + QuoraConstant.vectorized_path)
    clinica_vectorizer = joblib.load(project_root_dir + '\\' + ClinicalConstant.vectorized_path)

    @staticmethod
    def get_vectorize(query, dataset):
        if dataset == QuoraConstant.name:
            query_vector = VectorizeQuery.quora_vectorizer
        else:
            query_vector = VectorizeQuery.clinica_vectorizer
        return query_vector.transform([query])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 6
#       2 import joblib
#       3 from utils.constant import QuoraConstant, ClinicalConstant
# ----> 6 class VectorizeQuery:
#       7     project_root_dir = os.path.join(
#       8        os.path.dirname(os.path.abspath('')),
#       9         'vectorizer')
#      10     quora_vectorizer = joblib.load( project_root_dir + '\\' + QuoraConstant.vectorized_path)
#
# Cell In[18], line 10, in VectorizeQuery()
#       6 class VectorizeQuery:
#       7     project_root_dir = os.path.join(
#       8        os.path.dirname(os.path.abspath('')),
#       9         'vectorizer')
# ---> 10     quora_vectorizer = joblib.load( project_root_dir + '\\' + QuoraConstant.vectorized_path)
#      11     clinica_vectorizer = joblib.load(project_root_dir + '\\' + ClinicalConstant.vectorized_path)
#      13     @staticmethod
#      14     def get_vectorize(query, dataset):
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\joblib\numpy_pickle.py:658, in load(filename, mmap_mode)
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#     656                 return load_compatibility(fobj)
# --> 658             obj = _unpickle(fobj, filename, mmap_mode)
#     659 return obj
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\joblib\numpy_pickle.py:577, in _unpickle(fobj, filename, mmap_mode)
#     575 obj = None
#     576 try:
# --> 577     obj = unpickler.load()
#     578     if unpickler.compat_mode:
#     579         warnings.warn("The file '%s' has been generated with a "
#     580                       "joblib version less than 0.10. "
#     581                       "Please regenerate this pickle file."
#     582                       % filename,
#     583                       DeprecationWarning, stacklevel=3)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\pickle.py:1210, in _Unpickler.load(self)
#    1208             raise EOFError
#    1209         assert isinstance(key, bytes_types)
# -> 1210         dispatch[key[0]](self)
#    1211 except _Stop as stopinst:
#    1212     return stopinst.value
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\pickle.py:1535, in _Unpickler.load_stack_global(self)
#    1533 if type(name) is not str or type(module) is not str:
#    1534     raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1535 self.append(self.find_class(module, name))
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\pickle.py:1577, in _Unpickler.find_class(self, module, name)
#    1575     elif module in _compat_pickle.IMPORT_MAPPING:
#    1576         module = _compat_pickle.IMPORT_MAPPING[module]
# -> 1577 __import__(module, level=0)
#    1578 if self.proto >= 4:
#    1579     return _getattribute(sys.modules[module], name)[0]
#
# File c:\Users\ASUS\PycharmProjects\ir_full_project\flask_module\offline\text_processing\text_processing.py:7
#       5 from .utils.date import _normalize_dates
#       6 from .utils.lemmatize import lemmatize_words
# ----> 7 from .utils.medical_abbreviations import replace_medical_abbreviations_text
#       8 from .utils.nomalize_number import convert_numbers, remove_commas_from_numbers
#       9 from .utils.lower import lowercase_letters
#
# File c:\Users\ASUS\PycharmProjects\ir_full_project\flask_module\offline\text_processing\utils\medical_abbreviations.py:6
#       2 import spacy
#       3 from scispacy.abbreviation import AbbreviationDetector
# ----> 6 class nlpIn:
#       7     nlp = spacy.load("en_core_sci_md")
#       8     # Add the abbreviation pipe to the spacy pipeline.
#
# File c:\Users\ASUS\PycharmProjects\ir_full_project\flask_module\offline\text_processing\utils\medical_abbreviations.py:7, in nlpIn()
#       6 class nlpIn:
# ----> 7     nlp = spacy.load("en_core_sci_md")
#       8     # Add the abbreviation pipe to the spacy pipeline.
#       9     nlp.add_pipe("abbreviation_detector")
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\spacy\__init__.py:50, in load(name, vocab, disable, exclude, config)
#      29 def load(
#      30     name: Union[str, Path],
#      31     *,
#    (...)
#      35     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      36 ) -> Language:
#      37     """Load a spaCy model from an installed package or a local path.
#      38
#      39     name (str): Package name or model path.
#    (...)
#      48     RETURNS (Language): The loaded nlp object.
#      49     """
# ---> 50     return util.load_model(
#      51         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      52     )
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\spacy\util.py:324, in load_model(name, vocab, disable, exclude, config)
#     322     return get_lang_class(name.replace("blank:", ""))()
#     323 if is_package(name):  # installed as package
# --> 324     return load_model_from_package(name, **kwargs)
#     325 if Path(name).exists():  # path to model data directory
#     326     return load_model_from_path(Path(name), **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\spacy\util.py:357, in load_model_from_package(name, vocab, disable, exclude, config)
#     342 """Load a model from an installed package.
#     343
#     344 name (str): The package name.
#    (...)
#     354 RETURNS (Language): The loaded nlp object.
#     355 """
#     356 cls = importlib.import_module(name)
# --> 357 return cls.load(vocab=vocab, disable=disable, exclude=exclude, config=config)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\en_core_sci_md\__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\spacy\util.py:517, in load_model_from_init_py(init_file, vocab, disable, exclude, config)
#     515 if not model_path.exists():
#     516     raise IOError(Errors.E052.format(path=data_path))
# --> 517 return load_model_from_path(
#     518     data_path,
#     519     vocab=vocab,
#     520     meta=meta,
#     521     disable=disable,
#     522     exclude=exclude,
#     523     config=config,
#     524 )
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\spacy\util.py:392, in load_model_from_path(model_path, meta, vocab, disable, exclude, config)
#     390 overrides = dict_to_dot(config)
#     391 config = load_config(config_path, overrides=overrides)
# --> 392 nlp = load_model_from_config(config, vocab=vocab, disable=disable, exclude=exclude)
#     393 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\spacy\util.py:429, in load_model_from_config(config, vocab, disable, exclude, auto_fill, validate)
#     426 # This will automatically handle all codes registered via the languages
#     427 # registry, including custom subclasses provided via entry points
#     428 lang_cls = get_lang_class(nlp_config["lang"])
# --> 429 nlp = lang_cls.from_config(
#     430     config,
#     431     vocab=vocab,
#     432     disable=disable,
#     433     exclude=exclude,
#     434     auto_fill=auto_fill,
#     435     validate=validate,
#     436 )
#     437 return nlp
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\spacy\language.py:1672, in Language.from_config(cls, config, vocab, disable, exclude, meta, auto_fill, validate)
#    1669     factory = pipe_cfg.pop("factory")
#    1670     # The pipe name (key in the config) here is the unique name
#    1671     # of the component, not necessarily the factory
# -> 1672     nlp.add_pipe(
#    1673         factory,
#    1674         name=pipe_name,
#    1675         config=pipe_cfg,
#    1676         validate=validate,
#    1677         raw_config=raw_config,
#    1678     )
#    1679 else:
#    1680     model = pipe_cfg["source"]
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\spacy\language.py:774, in Language.add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     766     if not self.has_factory(factory_name):
#     767         err = Errors.E002.format(
#     768             name=factory_name,
#     769             opts=", ".join(self.factory_names),
#    (...)
#     772             lang_code=self.lang,
#     773         )
# --> 774     pipe_component = self.create_pipe(
#     775         factory_name,
#     776         name=name,
#     777         config=config,
#     778         raw_config=raw_config,
#     779         validate=validate,
#     780     )
#     781 pipe_index = self._get_pipe_index(before, after, first, last)
#     782 self._pipe_meta[name] = self.get_factory_meta(factory_name)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\spacy\language.py:660, in Language.create_pipe(self, factory_name, name, config, raw_config, validate)
#     657 cfg = {factory_name: config}
#     658 # We're calling the internal _fill here to avoid constructing the
#     659 # registered functions twice
# --> 660 resolved = registry.resolve(cfg, validate=validate)
#     661 filled = registry.fill({"cfg": cfg[factory_name]}, validate=validate)["cfg"]
#     662 filled = Config(filled)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\thinc\config.py:746, in registry.resolve(cls, config, schema, overrides, validate)
#     737 @classmethod
#     738 def resolve(
#     739     cls,
#    (...)
#     744     validate: bool = True,
#     745 ) -> Dict[str, Any]:
# --> 746     resolved, _ = cls._make(
#     747         config, schema=schema, overrides=overrides, validate=validate, resolve=True
#     748     )
#     749     return resolved
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\thinc\config.py:795, in registry._make(cls, config, schema, overrides, resolve, validate)
#     793 if not is_interpolated:
#     794     config = Config(orig_config).interpolate()
# --> 795 filled, _, resolved = cls._fill(
#     796     config, schema, validate=validate, overrides=overrides, resolve=resolve
#     797 )
#     798 filled = Config(filled, section_order=section_order)
#     799 # Check that overrides didn't include invalid properties not in config
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\thinc\config.py:850, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     848     schema.__fields__[key] = copy_model_field(field, Any)
#     849 promise_schema = cls.make_promise_schema(value, resolve=resolve)
# --> 850 filled[key], validation[v_key], final[key] = cls._fill(
#     851     value,
#     852     promise_schema,
#     853     validate=validate,
#     854     resolve=resolve,
#     855     parent=key_parent,
#     856     overrides=overrides,
#     857 )
#     858 reg_name, func_name = cls.get_constructor(final[key])
#     859 args, kwargs = cls.parse_args(final[key])
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\thinc\config.py:849, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     847     field = schema.__fields__[key]
#     848     schema.__fields__[key] = copy_model_field(field, Any)
# --> 849 promise_schema = cls.make_promise_schema(value, resolve=resolve)
#     850 filled[key], validation[v_key], final[key] = cls._fill(
#     851     value,
#     852     promise_schema,
#    (...)
#     856     overrides=overrides,
#     857 )
#     858 reg_name, func_name = cls.get_constructor(final[key])
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\thinc\config.py:1057, in registry.make_promise_schema(cls, obj, resolve)
#    1055         sig_args[name] = (annotation, default)
#    1056 sig_args["__config__"] = _PromiseSchemaConfig
# -> 1057 return create_model("ArgModel", **sig_args)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\pydantic\main.py:990, in pydantic.main.create_model()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\pydantic\main.py:299, in pydantic.main.ModelMetaclass.__new__()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\pydantic\fields.py:411, in pydantic.fields.ModelField.infer()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\pydantic\fields.py:342, in pydantic.fields.ModelField.__init__()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\pydantic\fields.py:451, in pydantic.fields.ModelField.prepare()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\pydantic\fields.py:550, in pydantic.fields.ModelField._type_analysis()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\typing.py:774, in _GenericAlias.__subclasscheck__(self, cls)
#     772 if self._special:
#     773     if not isinstance(cls, _GenericAlias):
# --> 774         return issubclass(cls, self.__origin__)
#     775     if cls._special:
#     776         return issubclass(cls.__origin__, self.__origin__)
#
# TypeError: issubclass() arg 1 must be a class

# %%
from sklearn.metrics.pairwise import cosine_similarity
from utils.constant import QuoraConstant, ClinicalConstant
from typing import Dict
import numpy as np

def ranking(query: str, dataset: str, tfidf_matrix) -> Dict[str, float]:
    if dataset == QuoraConstant.name:
        cosine_threshold = QuoraConstant.cosine_threshold
    else:
        cosine_threshold = ClinicalConstant.cosine_threshold
    query_vector = VectorizeQuery.get_vectorize(query, dataset)
    similarities = cosine_similarity(query_vector, tfidf_matrix)
    matched_indices = similarities.argsort()[0][::-1].flatten()
    top_indices = []
    for i in matched_indices:
        if similarities[0][i] >= cosine_threshold:
            top_indices.append(i.item())
    results = {}
    for index in top_indices:
        doc_id = str(index)
        similarity = similarities[0][index]
        results[doc_id] = similarity
    return results


def ranking_with_clustering(query: str, dataset: str, tfidf_matrix, kmeans_model, clustered_labels) -> Dict[str, float]:
    # JOUDI
    # Evaluation
    # score
    # with clustering for beir / quora / test: {RR: 0.6694122373068397, P @ 10: 0.09851000000001268,
    #                                           R @ 10: 0.7346798446145515, AP: 0.6244075488048499}
    # JOUDI
    # if dataset == QuoraConstant.name:
    #     cosine_threshold = QuoraConstant.cosine_threshold
    # else:
    #     cosine_threshold = ClinicalConstant.cosine_threshold
    #
    # query_vector = VectorizeQuery.get_vectorize(query, dataset)
    # target_cluster = kmeans_model.predict(query_vector.reshape(1, -1))[0]
    #
    # cluster_indices = np.where(np.array(clustered_labels) == target_cluster)[0]
    # cluster_matrix = tfidf_matrix[cluster_indices]
    #
    # similarities = cosine_similarity(query_vector.reshape(1, -1), cluster_matrix)
    # top_indices = np.where(similarities >= cosine_threshold)[1]
    #
    # results = {}
    # for index in top_indices:
    #     doc_id = str(cluster_indices[index])  # Adjusted to return the correct document indices
    #     similarity = similarities[0][index]
    #     results[doc_id] = similarity
    #
    # return results
    ############################
    # GPT Evaluation score with clustering for beir/quora/test: {R@10: 0.734706035090742, AP: 0.6180022150081328,
    # P@10: 0.09851000000001268, RR: 0.6663341269841242}
    # GPT
    # if dataset == QuoraConstant.name:
    #     cosine_threshold = QuoraConstant.cosine_threshold
    # else:
    #     cosine_threshold = ClinicalConstant.cosine_threshold
    #
    # query_vector = VectorizeQuery.get_vectorize(query, dataset)
    # target_cluster = kmeans_model.predict(query_vector.reshape(1, -1))[0]
    #
    # cluster_indices = np.where(np.array(clustered_labels) == target_cluster)[0]
    # cluster_matrix = tfidf_matrix[cluster_indices]
    #
    # similarities = cosine_similarity(query_vector.reshape(1, -1), cluster_matrix)
    #
    # top_indices = np.argsort(similarities[0])[-10:][::-1]  # Getting top 10 indices
    #
    # results = {}
    # for index in top_indices:
    #     doc_id = str(cluster_indices[index])
    #     similarity = similarities[0][index]
    #     results[doc_id] = similarity
    #
    # return results
    #################################
    # GPT4
    if dataset == QuoraConstant.name:
        cosine_threshold = QuoraConstant.cosine_threshold
    else:
        cosine_threshold = ClinicalConstant.cosine_threshold

    query_vector = VectorizeQuery.get_vectorize(query, dataset)
    target_cluster = kmeans_model.predict(query_vector.reshape(1, -1))[0]

    cluster_indices = np.where(np.array(clustered_labels) == target_cluster)[0]
    cluster_matrix = tfidf_matrix[cluster_indices]

    similarities = cosine_similarity(query_vector.reshape(1, -1), cluster_matrix)

    # First, filter documents using a similarity threshold
    threshold_indices = np.where(similarities >= cosine_threshold)[1]

    # Then, rank the filtered documents based on their similarity scores
    ranked_indices = np.argsort(similarities[0][threshold_indices])[-10:][::-1]  # Rank top 10 from filtered indices

    results = {}
    for index in ranked_indices:
        doc_id = str(cluster_indices[threshold_indices[index]])
        similarity = similarities[0][threshold_indices[index]]
        results[doc_id] = similarity

    return results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 def ranking(query: str, dataset: str, tfidf_matrix) -> Dict[str, float]:
#       2     if dataset == "quora":
#       3         cosine_threshold = 0.3
#
# NameError: name 'Dict' is not defined

# %%
from pymongo import MongoClient
def customize_result_from_index_to_doc_id(result, dataset: str):
    mongo_client = MongoClient('localhost', 27017)
    db = mongo_client['IR_DOCS']
    collection = db[dataset]
    data = collection.find({"index": {"$in": [int(s) for s in list(result)]}}, {'_id': 1, 'index': 1})
    new_result = {}
    for item in data:
        new_result[item['_id']] = result[str(item['index'])]
    return new_result

# %%
def retrieve(query, dataset, tfidf_matrix) -> Dict[str, float]:
    result = ranking(query, dataset, tfidf_matrix)
    return customize_result_from_index_to_doc_id(result, dataset)


def retrieve_with_clustering(query, dataset, tfidf_matrix, kmeans_model, cluster_labels) -> Dict[str, float]:
    result = ranking_with_clustering(query, dataset, tfidf_matrix, kmeans_model, cluster_labels)
    return customize_result_from_index_to_doc_id(result, dataset)

# %%
# Evaluate the dataset
import os

import ir_measures
import joblib
from ir_measures import R, AP, P, RR

from offline.indexing.utils.tfidf_matrix_operation import load_tfidf_matrix

from utils.constant import QuoraConstant, ClinicalConstant

from offline.indexing.utils.kmeans_clusters_operations import load_cluster_labels


def evaluate(dataset_collection, dataset_name):
    qrels = dataset_collection.qrels_iter()
    queries = dataset_collection.queries_iter()
    ranking_docs = dict()
    i = 0
    tfidf_matrix = load_tfidf_matrix(dataset_name)
    for query in queries:
        if dataset_name == QuoraConstant.name:
            retrieved_docs = retrieve(query.text, dataset_name, tfidf_matrix)
        else:
            if query.other == 'None':
                text = query.disease + ' ' + query.gene + ' ' + query.demographic
            else:
                text = query.disease + ' ' + query.gene + ' ' + query.demographic + ' ' + query.other
            print(text)
            retrieved_docs = retrieve(text, dataset_name, tfidf_matrix)
        ranking_docs[query.query_id] = retrieved_docs
        i += 1
        if i % 100 == 0:
            print(i)
    metrics = [AP(rel=1), P(rel=1) @ 10, R(rel=1) @ 10, RR(rel=1)]
    qrels_map = dict()
    for qrel in qrels:
        if qrel.query_id in ranking_docs.keys():
            if qrel.query_id in qrels_map:
                qrels_map[qrel.query_id].update({qrel.doc_id: qrel.relevance})
            else:
                qrels_map[qrel.query_id] = {qrel.doc_id: qrel.relevance}
    score = ir_measures.calc_aggregate(metrics, qrels_map, ranking_docs)
    return score


def evaluate_with_clustering(dataset_collection, dataset_name):
    qrels = dataset_collection.qrels_iter()
    queries = dataset_collection.queries_iter()
    ranking_docs = dict()
    i = 0
    tfidf_matrix = load_tfidf_matrix(dataset_name)
    clustering_labels = load_cluster_labels(dataset_name)
    project_root_dir = os.path.join(
        os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(__file__))))),
        'clustering')
    if dataset_name == QuoraConstant.name:
        cluster_model = joblib.load(project_root_dir + '\\' + QuoraConstant.cluster_path)
    else:
        cluster_model = joblib.load(project_root_dir + '\\' + ClinicalConstant.cluster_path)
    for query in queries:
        if dataset_name == QuoraConstant.name:
            retrieved_docs = retrieve_with_clustering(query.text, dataset_name, tfidf_matrix, cluster_model,
                                                      clustering_labels)
        else:
            if query.other == 'None':
                text = query.disease + ' ' + query.gene + ' ' + query.demographic
            else:
                text = query.disease + ' ' + query.gene + ' ' + query.demographic + ' ' + query.other
            print(text)
            retrieved_docs = retrieve_with_clustering(text, dataset_name, tfidf_matrix, cluster_model,
                                                      clustering_labels)
        ranking_docs[query.query_id] = retrieved_docs
        i += 1
        if i % 100 == 0:
            print(i)
    metrics = [AP(rel=1), P(rel=1) @ 10, R(rel=1) @ 10, RR(rel=1)]
    qrels_map = dict()
    for qrel in qrels:
        if qrel.query_id in ranking_docs.keys():
            if qrel.query_id in qrels_map:
                qrels_map[qrel.query_id].update({qrel.doc_id: qrel.relevance})
            else:
                qrels_map[qrel.query_id] = {qrel.doc_id: qrel.relevance}
    score = ir_measures.calc_aggregate(metrics, qrels_map, ranking_docs)
    return score
